# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("C:\\Users\\Robin\\Desktop\\test2.jpg")

#plt.figure(figsize=(100,50))
plt.imshow(image)
plt.title("input image"), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'input image'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
image2 = cv2.imread("C:\\Users\\Robin\\Desktop\\test3.jpg")

#plt.figure(figsize=(100,50))
plt.imshow(image2)
plt.title("input image2"), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'input image2'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
#選擇性探索主要運用套件 selectivesearch.astronaut
#import skimage.data
import selectivesearch
import numpy as np

#image = np.array(image)
#image = image.tolist()

#img = image.astronaut()
img_lbl,regions = selectivesearch.selective_search(image2,scale=500,sigma=0.9,min_size=10)

regions[:10]
# Out:
# [{'rect': (0, 0, 34, 106), 'size': 1558, 'labels': [0.0]},
#  {'rect': (8, 0, 9, 26), 'size': 113, 'labels': [1.0]},
#  {'rect': (13, 0, 187, 126), 'size': 12070, 'labels': [2.0]},
#  {'rect': (155, 13, 14, 25), 'size': 66, 'labels': [3.0]},
#  {'rect': (0, 14, 3, 8), 'size': 36, 'labels': [4.0]},
#  {'rect': (152, 14, 16, 73), 'size': 776, 'labels': [5.0]},
#  {'rect': (58, 20, 57, 45), 'size': 1447, 'labels': [6.0]},
#  {'rect': (85, 24, 32, 82), 'size': 280, 'labels': [7.0]},
#  {'rect': (150, 24, 3, 22), 'size': 67, 'labels': [8.0]},
#  {'rect': (14, 25, 9, 33), 'size': 77, 'labels': [9.0]}]

# %%
img_lbl2,regions2 = selectivesearch.selective_search(image,scale=500,sigma=0.9,min_size=10)

regions2[:10]
# Out:
# [{'rect': (0, 0, 325, 154), 'size': 37256, 'labels': [0.0]},
#  {'rect': (194, 10, 5, 6), 'size': 31, 'labels': [1.0]},
#  {'rect': (124, 13, 7, 5), 'size': 35, 'labels': [2.0]},
#  {'rect': (12, 15, 119, 41), 'size': 1036, 'labels': [3.0]},
#  {'rect': (83, 16, 3, 3), 'size': 12, 'labels': [4.0]},
#  {'rect': (177, 19, 33, 32), 'size': 448, 'labels': [5.0]},
#  {'rect': (218, 19, 13, 32), 'size': 97, 'labels': [6.0]},
#  {'rect': (226, 19, 53, 44), 'size': 663, 'labels': [7.0]},
#  {'rect': (270, 19, 21, 32), 'size': 187, 'labels': [8.0]},
#  {'rect': (21, 21, 15, 9), 'size': 68, 'labels': [9.0]}]

# %%
import matplotlib.patches as mpatches
candidates = set()
for r in regions:
    if r['rect'] in candidates:
        continue
        # excluding regions smaller than 2000 pixels
    if r['size'] < 2000:
        continue
        # distorted rects
    x, y, w, h = r['rect']
    if w / h > 1.2 or h / w > 1.2:
        continue
    candidates.add(r['rect'])

    # draw rectangles on the original image
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.imshow(image2)
for x, y, w, h in candidates:
    print(x, y, w, h)
    rect = mpatches.Rectangle(
        (x, y), w, h, fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)

plt.show()
# Out:
# 109 157 78 75
# 6 99 131 122
# 17 143 97 92
# 0 0 200 196
# 0 0 200 174

# %%
candidates = set()
for r in regions:
    if r['rect'] in candidates:
        continue
        # excluding regions smaller than 2000 pixels
    if r['size'] < 2000:
        continue
        # distorted rects
    x, y, w, h = r['rect']
    if w / h > 1.2 or h / w > 1.2:
        continue
    candidates.add(r['rect'])

    # draw rectangles on the original image
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.imshow(image)
for x, y, w, h in candidates:
    print(x, y, w, h)
    rect = mpatches.Rectangle(
        (x, y), w, h, fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)

plt.show()
# Out:
# 109 157 78 75
# 6 99 131 122
# 17 143 97 92
# 0 0 200 196
# 0 0 200 174
